# %%
import turtle
pen  = turtle.Turtle()
pen.pensize(5)
pen.speed(9)
#turtle go to original position
# def move_to_original()
pen.penup()
pen.goto(-300, -200)
pen.pendown()
# pen.right(45)
#Draw house
    #blue square (x1)
pen.fillcolor("blue")
pen.begin_fill()
for i in range(4):
    pen.forward(150)
    pen.left(90)
pen.end_fill()
    #green rectangle(x2, x3)
pen.penup()
pen.goto(-200, -200)
pen.pendown
pen.fillcolor("green")
pen.begin_fill()
for i in range(2):
    pen.left(90)
    pen.forward(70)
    pen.left(90)
    pen.forward(50)
pen.end_fill()
    #violet triangle (x1, x1/2^0.5)
pen.penup()
pen.goto(-150, -200)
pen.pendown
pen.fillcolor("violet")
pen.begin_fill()  
pen.right(90)
    #orange parallelogram
pen.penup()
pen.goto(-150, -200)
pen.pendown
pen.fillcolor("yellow")
pen.begin_fill()
pen.left(35)
pen.forward(106.0660171779821)
pen.left(55)
pen.fd(150)
pen.left(125)
pen.fd(106.0660171779821)
pen.end_fill()      
    #yellow parallelogram
    
    #brown parallelogram

#Draw tree
from turtle import Turtle

pen = Turtle()

pen.speed(9)

    # ve la cay

pen.pencolor("#21610B")
             
pen.fillcolor("#21610B")
pen.begin_fill()

pen.right(180)
pen.goto(0,40)
pen.circle(50, steps = 3)
pen.end_fill()

pen.penup()
pen.goto(0,10)
pen.pendown()

pen.fillcolor("#21610B")
pen.begin_fill()


pen.circle(50, steps = 3)
pen.end_fill()

pen.penup()
pen.goto(0,-20)
pen.pendown()

pen.fillcolor("#21610B")
pen.begin_fill()


pen.circle(50, steps = 3)
pen.end_fill()

    # ve than cay
    pen.penup()
    pen.goto(19,-95)
    pen.pendown()

    pen.pencolor("#886A08")

    pen.fillcolor("#886A08")
    pen.begin_fill()

    pen.left(90)

    pen.forward(100)
    pen.right(90)
    pen.forward(40)
    pen.right(90)
    pen.forward(100)
    pen.right(90)
    pen.forward(40)

    pen.end_fill()


    turtle.done()

    #triangle(100)
    
    #Triangle(184)
    
    #Triangle(274)
    
    #Brown Rectangle
    
#Draw sun
    #yellow circle
    
    #long line * 4
    
    #short line * 4

#turtle go to original position

turtle.done()
